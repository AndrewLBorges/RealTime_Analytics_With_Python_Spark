# %% [markdown]
# # <font color='blue'>Big Data Real-Time Analytics com Python e Spark</font>
#
# ## <font color='blue'>Mini-Projeto 2</font>
#
# ### <font color='blue'>Processo de Construção, Treinamento, Avaliação e Seleção de Modelos Para Regressão</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
#!pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
#!pip install -q -U watermark
# Out:
# Requirement already satisfied: seaborn in c:\users\andrew\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\andrew\anaconda3\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\andrew\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\andrew\anaconda3\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrew\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andrew\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andrew\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\andrew\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andrew\anaconda3\lib\site-packages)

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score
sns.set_style('whitegrid')
# %matplotlib inline
# import warnings
# warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Andrew Borges" --iversions
# Out:
# Author: Andrew Borges
#
# numpy     : 1.22.3
# pandas    : 1.5.3
# seaborn   : 0.12.2
# matplotlib: 3.7.1
# sklearn   : 0.0.post1

# %% [markdown]
# ## Carregando o Conjunto de dados

# %%
# Carrega o dataset
dados = pd.read_csv('dados/dataset.csv')

# %%
# Shape
dados.shape
# Out:
# (500, 5)

# %%
# Info
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   tempo_cadastro_cliente           500 non-null    float64
#  1   numero_medio_cliques_por_sessao  500 non-null    float64
#  2   tempo_total_logado_app           500 non-null    float64
#  3   tempo_total_logado_website       500 non-null    float64
#  4   valor_total_gasto                500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB

# %%
# Amostra
dados.sample(10)
# Out:
#      tempo_cadastro_cliente  numero_medio_cliques_por_sessao  \
# 337                3.205530                        31.309193
# 329                1.482360                        33.908565
# 392                3.525806                        32.602739
# 256                1.139094                        32.078948
# 13                 1.707390                        32.246350
# 412                3.561215                        33.593964
# 321                3.236733                        32.262003
# 477                2.571778                        32.675155
# 295                3.557814                        31.724203
# 208                2.873008                        33.630801
#
#      tempo_total_logado_app  tempo_total_logado_website  valor_total_gasto
# 337               11.947175                   36.190833         432.720718
# 329               12.914847                   39.068864         432.472061
# 392               11.764448                   37.922704         482.144997
# 256               12.725909                   36.544664         357.863719
# 13                11.305551                   37.133127         327.377953
# 412               11.520567                   36.189132         474.532329
# 321               11.644970                   37.026877         442.363117
# 477               12.594194                   37.683875         444.582165
# 295               13.172287                   36.199753         503.387887
# 208               12.039648                   38.924087         497.811930

# %% [markdown]
# ## Análise Exploratória de Dados

# %%
dados.columns
# Out:
# Index(['tempo_cadastro_cliente', 'numero_medio_cliques_por_sessao',
#        'tempo_total_logado_app', 'tempo_total_logado_website',
#        'valor_total_gasto'],
#       dtype='object')

# %%
# Correlação (tabela)
dados.corr()
# Out:
#                                  tempo_cadastro_cliente  \
# tempo_cadastro_cliente                         1.000000
# numero_medio_cliques_por_sessao                0.060247
# tempo_total_logado_app                         0.029143
# tempo_total_logado_website                    -0.047582
# valor_total_gasto                              0.809084
#
#                                  numero_medio_cliques_por_sessao  \
# tempo_cadastro_cliente                                  0.060247
# numero_medio_cliques_por_sessao                         1.000000
# tempo_total_logado_app                                 -0.027826
# tempo_total_logado_website                             -0.034987
# valor_total_gasto                                       0.355088
#
#                                  tempo_total_logado_app  \
# tempo_cadastro_cliente                         0.029143
# numero_medio_cliques_por_sessao               -0.027826
# tempo_total_logado_app                         1.000000
# tempo_total_logado_website                     0.082388
# valor_total_gasto                              0.499328
#
#                                  tempo_total_logado_website  valor_total_gasto
# tempo_cadastro_cliente                            -0.047582           0.809084
# numero_medio_cliques_por_sessao                   -0.034987           0.355088
# tempo_total_logado_app                             0.082388           0.499328
# tempo_total_logado_website                         1.000000          -0.002641
# valor_total_gasto                                 -0.002641           1.000000

# %%
# Correlação (visual)
sns.pairplot(dados)

# %% [markdown]
# ### Análise 1 - Relação Entre Tempo no Web Site e Valor Gasto

# %%
# Plot
plt.figure(figsize= (18, 12))
sns.set(font_scale = 1.1)
sns.jointplot(data = dados,
             x = 'tempo_total_logado_website',
             y = 'valor_total_gasto',
             color = 'blue')

# %% [markdown]
# Observando os histogramas, podemos ver que os dados estão normalmente distribuídos (seguem uma distribuição normal).
#
# Observando o gráfico de dispersão, não parece haver correlação entre as duas variáveis. Vamos confirmar calculando o coeficiente de correlação entre elas.

# %%
# Correlação
dados[['tempo_total_logado_website', 'valor_total_gasto']].corr()
# Out:
#                             tempo_total_logado_website  valor_total_gasto
# tempo_total_logado_website                    1.000000          -0.002641
# valor_total_gasto                            -0.002641           1.000000

# %% [markdown]
# Não parece haver correlação entre o tempo logado no web site e o valor gasto pelos clientes.

# %% [markdown]
# ### Análise 2 - Relação Entre Tempo na App e Valor Gasto

# %%
# Colunas
dados.columns
# Out:
# Index(['tempo_cadastro_cliente', 'numero_medio_cliques_por_sessao',
#        'tempo_total_logado_app', 'tempo_total_logado_website',
#        'valor_total_gasto'],
#       dtype='object')

# %%
# Plot
plt.figure(figsize= (18, 12))
sns.set(font_scale = 1.2)
sns.jointplot(data = dados,
             x = 'tempo_total_logado_app',
             y = 'valor_total_gasto',
             color = 'green')

# %% [markdown]
# Observando os histogramas, podemos ver que os dados estão normalmente distribuídos (seguem uma distribuição normal).
#
# Observando o gráfico de dispersão, parece haver correlação positiva entre as duas variáveis. Vamos confirmar calculando o coeficiente de correlação entre elas.

# %%
# Correlação
dados[['tempo_total_logado_app', 'valor_total_gasto']].corr()
# Out:
#                         tempo_total_logado_app  valor_total_gasto
# tempo_total_logado_app                1.000000           0.499328
# valor_total_gasto                     0.499328           1.000000

# %% [markdown]
# Os dados têm uma correlação positiva moderada. Podemos deduzir que o valor total gasto mensalmente tende a aumentar se o cliente passar mais tempo logado na app.

# %% [markdown]
# ### Análise 3 - Relação Entre Tempo na App e Tempo de Cadastro

# %%
# Colunas
dados.columns
# Out:
# Index(['tempo_cadastro_cliente', 'numero_medio_cliques_por_sessao',
#        'tempo_total_logado_app', 'tempo_total_logado_website',
#        'valor_total_gasto'],
#       dtype='object')

# %%
# Plot
plt.figure(figsize=(18, 12))
sns.set(font_scale = 1.2)
sns.jointplot(data = dados,
             x = 'tempo_total_logado_app',
             y = 'tempo_cadastro_cliente',
             color = 'red')

# %% [markdown]
# Observando os histogramas, podemos ver que os dados estão normalmente distribuídos (seguem uma distribuição normal).
#
# A partir do gráfico de dispersão podemos ver que os dados são muito densos no meio do gráfico, não havendo uma correlação clara. Podemos deduzir que existem muitos clientes que são membros há 3-4 anos e gastam aproximadamente 11,5 a 12,5 minutos na app.

# %% [markdown]
# ### Análise 4 - Relação Entre Tempo de Cadastro e Valor Gasto

# %%
# Colunas
dados.columns
# Out:
# Index(['tempo_cadastro_cliente', 'numero_medio_cliques_por_sessao',
#        'tempo_total_logado_app', 'tempo_total_logado_website',
#        'valor_total_gasto'],
#       dtype='object')

# %%
# Plot
sns.set(font_scale = 1.1)
sns.set_style('whitegrid')
sns.lmplot(y = 'valor_total_gasto', x = 'tempo_cadastro_cliente', data = dados)

# %%
# Correlação
dados[['tempo_cadastro_cliente', 'valor_total_gasto']].corr()
# Out:
#                         tempo_cadastro_cliente  valor_total_gasto
# tempo_cadastro_cliente                1.000000           0.809084
# valor_total_gasto                     0.809084           1.000000

# %% [markdown]
# A partir do lmplot e do coeficiente de correlação, podemos ver que o tempo de cadstro e o valor total gasto têm uma forte correlação positiva, ou seja, à medida que o cliente se torna mais antigo (mais tempo de cadastro), o valor total gasto por clientes também aumenta.
#
# Outra coisa a se notar é que a sombra ao redor da linha é muito fina, o que significa que os erros entre a estimativa (linha) e os pontos de dados são relativamente pequenos.

# %% [markdown]
# ### Análise 5 - Relação Entre Tempo Logado na App e Tempo Logado no Web Site

# %%
# Plot
plt.figure(figsize=(18, 12))
sns.set(font_scale = 1.2)
sns.jointplot(data = dados, x = 'tempo_total_logado_app', y = 'tempo_total_logado_website', color = 'magenta')

# %% [markdown]
# Não detectamos problemas críticos e podemos seguir adiante. Vamos manter a variável preditora com baixa correlação e validar essa relação com a variável alvo no modelo final.

# %% [markdown]
# ## Pré-Processamento de Dados Para Construção de Modelos de Machine Learning

# %%
dados.columns
# Out:
# Index(['tempo_cadastro_cliente', 'numero_medio_cliques_por_sessao',
#        'tempo_total_logado_app', 'tempo_total_logado_website',
#        'valor_total_gasto'],
#       dtype='object')

# %%
# Variáveis de entreada (variáveis preditoras)
X = dados[dados.columns[:-1]]

# %%
# Variável de saída (variável alvo ou target)
y = dados[dados.columns[-1:]]

# %%
y
# Out:
#      valor_total_gasto
# 0           534.771485
# 1           537.915753
# 2           407.876378
# 3           618.845970
# 4           502.771075
# ..                 ...
# 495         402.167122
# 496         551.023002
# 497         497.389558
# 498         494.638610
# 499         479.247417
#
# [500 rows x 1 columns]

# %%
# Divisão em dados de treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %%
len(X_treino)
# Out:
# 350

# %%
len(X_teste)
# Out:
# 150

# %% [markdown]
# ### Padronização

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_treino)
# Out:
# StandardScaler()

# %%
X_treino = scaler.transform(X_treino)

# %%
X_teste = scaler.transform(X_teste)

# %%
X_treino[:5]
# Out:
# array([[-0.21902935, -0.23735512,  0.33914084,  0.92765292],
#        [ 1.8073082 ,  0.09393489,  1.05266311,  0.2388907 ],
#        [-0.00962736, -0.47064535, -0.26005737,  0.81461639],
#        [-0.06171807, -0.23157636, -0.19229742, -0.26198867],
#        [-2.03669802, -1.54671013, -1.27813419,  1.65800995]])

# %%
X_teste[:5]
# Out:
# array([[-0.74134552,  0.35042401,  1.32428694,  0.85663193],
#        [ 0.51634261,  0.33850011,  1.36472848,  0.1071885 ],
#        [ 1.22462847, -0.84278168,  1.70184401,  0.88678948],
#        [ 0.48199668, -0.30436824, -0.65228214, -1.76956776],
#        [ 1.88519232, -0.14493923,  0.70658414, -1.44006612]])

# %% [markdown]
# ### Construção, Treinamento e Avaliação do Modelo 1 com Regressão Linear (Benchmark)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# ![title](imagens/linear1.png)

# %% [markdown]
# ![title](imagens/linear2.png)

# %% [markdown]
# ![title](imagens/linear3.png)

# %%
# Cria o modelo
modelo_v1 = LinearRegression()

# %%
# Treinamento
modelo_v1.fit(X_treino, y_treino)
# Out:
# LinearRegression()

# %%
print('Coeficientes: \n', modelo_v1.coef_)
# Out:
# Coeficientes:
#  [[63.74220716 26.23901606 38.57185551  0.6847366 ]]

# %%
# Coeficientes das variáveis preditoras
df_coef = pd.DataFrame(modelo_v1.coef_[0], X.columns, columns = ['Coeficiente'])
df_coef
# Out:
#                                  Coeficiente
# tempo_cadastro_cliente             63.742207
# numero_medio_cliques_por_sessao    26.239016
# tempo_total_logado_app             38.571856
# tempo_total_logado_website          0.684737

# %% [markdown]
# ### Avaliação do Modelo

# %%
# Previsões com dados de teste
pred_v1 = modelo_v1.predict(X_teste)

# %%
# Imprime as 10 primeiras previsões
pred_v1[:10]
# Out:
# array([[513.06429807],
#        [593.96597774],
#        [621.6550031 ],
#        [495.82353395],
#        [642.08919639],
#        [615.61800045],
#        [592.1273355 ],
#        [493.61084354],
#        [457.58835597],
#        [532.03644608]])

# %%
# plot
plt.figure(figsize = (10, 8))
plt.scatter(x = y_teste, y = pred_v1, color = 'skyblue', edgecolors = 'black')
plt.xlabel('Valor Real de Y')
plt.ylabel('Valor Previsto de Y');

# %% [markdown]
# A partir do gráfico de dispersão, podemos ver que há uma correlação muuito forte entre os y's previstos e os y's reais nos dados de teste. Isso significa que temos um modelo muito bom.

# %% [markdown]
# ### Métricas

# %%
# Valor médio gasto pelos clientes
dados['valor_total_gasto'].mean()
# Out:
# 499.31403826080003

# %%
# Valor mínimo
dados['valor_total_gasto'].min()
# Out:
# 256.6705823

# %%
# Valor máximo
dados['valor_total_gasto'].max()
# Out:
# 765.5184619

# %%
# MAE - Erro Médio Absoluto
mean_absolute_error(y_teste, pred_v1)
# Out:
# 7.762418645778979

# %% [markdown]
# > O MAE prevê que, em média, as previsões do noss modelo (de valores gastos) estão erradas em aproximadadmente 7,76 reais, o que é um valor pequeno comparado ao valor médio gasto por cliente.

# %%
# MSE - Erro Quadrático Médio
mean_squared_error(y_teste, pred_v1)
# Out:
# 94.95654308438662

# %%
# RMSE - Raiz quadrada do erro quadrático médio
np.sqrt(mean_squared_error(y_teste, pred_v1))
# Out:
# 9.744564797074656

# %% [markdown]
# O RMSE prevê que, em média, as previsões do noss modelo (de valores gastos) estão erradas em aproximadamente 9.74, que é um valor pequeno comparado ao valor médio gasto por cliente.

# %%
# Coeficiente R2
r2_score(y_teste, pred_v1)
# Out:
# 0.9813622791776302

# %%
# Variância Explicada
explained_variance_score(y_teste, pred_v1)
# Out:
# 0.9817449183428639

# %% [markdown]
# Nosso modelo é capaz de explicar 98% da variância dos dados, o que é excelente.
#
# O coeficiente R2 de 98% e as outras métricas, demonstram que este é um modelo muito bom. Será que conseguimos melhorar essa performance?

# %% [markdown]
# ### Resíduos

# %%
# Plot
plt.figure(figsize = (8,4))
ax = sns.histplot(data = (y_teste - pred_v1),
                  x = 'valor_total_gasto',
                  bins = 40,
                  kde_kws = dict(cut = 3),
                  kde = True,
                  stat = 'density',
                  edgecolor = 'black',
                  linewidth = 0.3,
                  color = 'red')
ax.set(xlim = (-40, 40))
ax.set(ylim = (0, 0.055));

# %% [markdown]
# Os resíduos são aproximadamente normalmente distribuídos, o que indica um bom ajuste do modelo.

# %% [markdown]
# ### Construção, Treinamento e Avaliação do Modelo 2 com Regressão Ridge
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html

# %%
# Cria o modelo
modelo_v2 = Ridge(alpha = 1.0)

# %%
# Treinamento
modelo_v2.fit(X_treino, y_treino)
# Out:
# Ridge()

# %%
print('Coeficientes: \n', modelo_v2.coef_)
# Out:
# Coeficientes:
#  [[63.57245999 26.17198131 38.46758178  0.68013543]]

# %%
# Coeficientes das variáveis preditoras
df_coef = pd.DataFrame(modelo_v2.coef_[0], X.columns, columns = ['Coeficiente'])
df_coef
# Out:
#                                  Coeficiente
# tempo_cadastro_cliente             63.572460
# numero_medio_cliques_por_sessao    26.171981
# tempo_total_logado_app             38.467582
# tempo_total_logado_website          0.680135

# %%
# Previsões com dados de teste
pred_v2 = modelo_v2.predict(X_teste)
pred_v2[:10]
# Out:
# array([[513.02461894],
#        [593.71284026],
#        [621.32208364],
#        [495.83827761],
#        [641.71185412],
#        [615.30802007],
#        [591.87884788],
#        [493.61867235],
#        [457.70805605],
#        [531.9426755 ]])

# %%
# Plot
plt.figure(figsize = (10, 8))
plt.scatter(x = y_teste, y = pred_v2, color = 'skyblue', edgecolors = 'black')
plt.xlabel('Valor Real de Y')
plt.ylabel('Valor Previsto de Y');

# %%
# MAE
mean_absolute_error(y_teste, pred_v2)
# Out:
# 7.764151148981961

# %%
# MSE
mean_squared_error(y_teste, pred_v2)
# Out:
# 94.93731602493465

# %%
# RMSE
np.sqrt(mean_squared_error(y_teste, pred_v2))
# Out:
# 9.7435781941202

# %%
# Coeficiente R2
r2_score(y_teste, pred_v2)
# Out:
# 0.981366052994101

# %%
# Variância Explicada
explained_variance_score(y_teste, pred_v2)
# Out:
# 0.9817472659016085

# %%
# Plot
plt.figure(figsize = (8,4))
ax = sns.histplot(data = (y_teste - pred_v2),
                  x = 'valor_total_gasto',
                  bins = 40,
                  kde_kws = dict(cut = 3),
                  kde = True,
                  stat = 'density',
                  edgecolor = 'black',
                  linewidth = 0.3,
                  color = 'red')
ax.set(xlim = (-40, 40))
ax.set(ylim = (0, 0.055));

# %% [markdown]
# ### Construção, Treinamento e Avaliação do Modelo 3 com Regressão LASSO
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html

# %%
# Cria o modelo
modelo_v3 = Lasso(alpha = 1.0)

# %%
# Treinamento
modelo_v3.fit(X_treino, y_treino)
# Out:
# Lasso()

# %%
print('Coeficientes: \n', modelo_v3.coef_)
# Out:
# Coeficientes:
#  [62.86344076 25.18747244 37.62149243  0.        ]

# %%
# Coeficientes
df_coef = pd.DataFrame(modelo_v3.coef_, X.columns, columns = ['Coeficiente'])
df_coef
# Out:
#                                  Coeficiente
# tempo_cadastro_cliente             62.863441
# numero_medio_cliques_por_sessao    25.187472
# tempo_total_logado_app             37.621492
# tempo_total_logado_website          0.000000

# %%
# Previsões com dados de teste
pred_v3 = modelo_v3.predict(X_teste)
pred_v3[:10]
# Out:
# array([511.50216083, 591.78590214, 619.24047552, 497.55162062,
#        640.89951717, 614.42803424, 590.05764493, 494.76617949,
#        459.30498489, 529.64197449])

# %%
# Plot
plt.figure(figsize = (10, 8))
plt.scatter(x = y_teste, y = pred_v3, color = 'skyblue', edgecolors = 'black')
plt.xlabel('Valor Real de Y')
plt.ylabel('Valor Previsto de Y');

# %%
# MAE
mean_absolute_error(y_teste, pred_v3)
# Out:
# 7.788504696951063

# %%
# MSE
mean_squared_error(y_teste, pred_v3)
# Out:
# 96.0560634897067

# %%
# RMSE
np.sqrt(mean_squared_error(y_teste, pred_v3))
# Out:
# 9.800819531534426

# %%
# Coeficiente R2
r2_score(y_teste, pred_v3)
# Out:
# 0.981146469358873

# %%
# Variância Explicada
explained_variance_score(y_teste, pred_v3)
# Out:
# 0.9815600649101045

# %%
# Plot
pred_v3 = pred_v3.reshape(pred_v3.shape[0], -1)
plt.figure(figsize = (8,4))
ax = sns.histplot(data = (y_teste - pred_v3),
                  x = 'valor_total_gasto',
                  bins = 40,
                  kde_kws = dict(cut = 3),
                  kde = True,
                  stat = 'density',
                  edgecolor = 'black',
                  linewidth = 0.3,
                  color = 'red')
ax.set(xlim = (-40, 40))
ax.set(ylim = (0, 0.055));

# %% [markdown]
# ### Seleção do Modelo

# %% [markdown]
# O modelo 3 apresentou uma taxa de erro (RMSE) levemente maior e pode ser descartado. Os modelos 1 e 2 ficaram muito próximos e nesse caso devemos escolher o modelo mais simples, que em nosso exemplo é o modelo 1.

# %% [markdown]
# ### Conclusão

# %%
dados.head()
# Out:
#    tempo_cadastro_cliente  numero_medio_cliques_por_sessao  \
# 0                3.472021                        33.119954
# 1                4.198349                        35.371876
# 2                2.086348                        33.976083
# 3                3.605934                        34.034164
# 4                4.034386                        32.770492
#
#    tempo_total_logado_app  tempo_total_logado_website  valor_total_gasto
# 0               12.953263                   37.034280         534.771485
# 1               10.572467                   36.862183         537.915753
# 2               11.658037                   37.425279         407.876378
# 3               13.592513                   36.838657         618.845970
# 4               11.371767                   35.261498         502.771075

# %%
# Coeficientes
df_coef_final = pd.DataFrame(modelo_v1.coef_[0], X.columns, columns = ['Coeficiente'])
df_coef_final
# Out:
#                                  Coeficiente
# tempo_cadastro_cliente             63.742207
# numero_medio_cliques_por_sessao    26.239016
# tempo_total_logado_app             38.571856
# tempo_total_logado_website          0.684737

# %% [markdown]
# **Interpretação dos Coeficientes:**
# - Mantendo todos os outros recursos fixos, um aumento de 1 unidade no tempo de cadastro do cliente está associado a um aumento de R\\$63.74 no valor total gasto por cliente por mês.
# - Mantendo todos os outros recursos fixos, um aumento de 1 unidade no número médio de cliques por sessão está associado a um aumento de R\\$26.24 no valor total gasto por cliente por mês.
# - Mantendo todos os outros recursos fixos, um aumento de 1 unidade no tempo total logado na app está associado a um aumento de R\\$38.57 no valor total gasto por cliente por mês.
# - Mantendo todos os outros recursos fixos, um aumento de 1 unidade no tempo total logado no website está associado a um aumento de R\\$0.68 no valor total gasto por cliente por mês.

# %% [markdown]
# Podemos ver que será mais lucrativo para a empresa investir na atualização da sua app uma vez que o retorno será maior. Além disso, é importante criar politicas para reter o cliente por mais tempo, já que isso também leva ao aumento das vendas. A própria atualização da app será uma forma de reter o cliente por mais tempo.
#
# Não compensa, neste momento, investir na atualização do web site pois o retorno será mínimo.

# %% [markdown]
# # Fim
